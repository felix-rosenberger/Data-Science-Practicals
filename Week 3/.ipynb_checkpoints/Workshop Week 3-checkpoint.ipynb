# %% [markdown]
# The goal of this week's workshop is to become familiar with the Pandas `DataFrame` data structure and begin looking at some simple data analysis and visualisation.   We'll look at two sample data sets and perform some analysis on them.

# %%
student_name = "Felix Rosenberger"
student_id = "46165991"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Auto MPG Data
#
# Our first exercise is with some data on cars from the US containing information about car size and power and fuel consumption (miles per gallon or mpg).   We'll use this to explore the Pandas `DataFrame` options for selecting and plotting data and for computing statistics over columns.
#
# First we read the data using `pd.read_table` since the data ([auto-mpg.data](files/auto-mpg.data)) is in a
# space separated tabular format (take a look at the raw data to see what this means).   I've added an
# explicit list of column headings and some options to `read_table` to get the data in the right format.

# %%
columns = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'modelyear', 'origin', 'name']
auto = pd.read_table('files/auto-mpg.data', delim_whitespace=True, header=None, names=columns)
auto.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  modelyear  \
# 0  18.0          8         307.0       130.0  3504.0          12.0         70
# 1  15.0          8         350.0       165.0  3693.0          11.5         70
# 2  18.0          8         318.0       150.0  3436.0          11.0         70
# 3  16.0          8         304.0       150.0  3433.0          12.0         70
# 4  17.0          8         302.0       140.0  3449.0          10.5         70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# Now that you have the data in a DataFrame, write code in cells below to do the following:
#
# * show the size of the data - how many rows and columns are there?
# * select just the `mpg` column, find the mean value of MPG for all cars
# * select all rows where the value of cylinders is 6, how many are there?
# * what is the mean MPG for 6 cylinder cars?
# * create a scatter plot of `mpg` vs `weight`
# * create a similar plot but just for the 8 cylinder cars
#
# You might want to refer to the [Pandas Tutorials](http://pandas.pydata.org/pandas-docs/stable/tutorials.html) or
#  [10 Minutes to Pandas](http://pandas.pydata.org/pandas-docs/stable/10min.html) for some hints.

# %%
# show the size of the data - how many rows and columns are there?
auto.shape
# Out:
# (392, 9)

# %%
# select just the mpg column, find the mean value of MPG for all cars
mean_mpg = auto["mpg"].mean()
print("The mean value for mpg is: ", round(mean_mpg, 2))
# Out:
# The mean value for mpg is:  23.45

# %%
# select all rows where the value of cylinders is 6, how many are there?
cyl6 = auto[auto["cylinders"] == 6]
cyl6["cylinders"].count()
# Out:
# 83

# %% [markdown]
# There are 83 rows where the value of cylinders is 6.

# %%
# what is the mean MPG for 6 cylinder cars?
mpg_6cyl = cyl6.mean(axis = 0)
print("The mean mpg for 6 cylinder cars is: ", mpg_6cyl["mpg"].round(2))
# Out:
# The mean mpg for 6 cylinder cars is:  19.97

# %%
# create a scatter plot of mpg vs weight
auto.plot(kind="scatter", x="mpg", y="weight")
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='weight'>

# %%
# create a similar plot but just for the 8 cylinder cars
cyl8 = auto[auto["cylinders"] == 8]
cyl8.plot(kind="scatter", x="mpg", y="weight")
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='weight'>

# %% [markdown]
# ## Adult Data Analysis
#
# Next we'll work with a dataset described in Chapter 3 of the text - the [Adult](https://archive.ics.uci.edu/ml/datasets/Adult) dataset:
#
# > "hosted on the UCI’s Machine Learning Repository.1 It contains approximately 32,000 observations concerning different financial parameters related to the US population: age, sex, marital (marital status of the individual), country, income (Boolean variable: whether the person makes more than $50,000 per annum), education (the highest level of education achieved by the individual), occupation, capital gain, etc.
#
# The data is stored in a file 'files/adult.data' in this repository. It is in CSV format but the text uses a
# different method to read it in to a dataframe - the reason is that it is a slightly non-standard format with spaces after the commas.  I've shown an alternate way to read the data below that uses read_csv with appropriate arguments to read the data.  This ensures that it doesn't try to read a header line (since there isn't one) and skips initial spaces in values.  We explicitly set the column names from a list of strings.

# %%
column_names = ['age', 'type_employer', 'fnlwgt', 'education', 'education_num', 
                'marital', 'occupation',' relationship', 'race', 'sex', 'capital_gain', 
                'capital_loss', 'hr_per_week', 'country', 'income']

adult = pd.read_csv('files/adult.data', header=None, names=column_names, skipinitialspace=True)
adult.head()
# Out:
#    age     type_employer  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#               marital         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hr_per_week        country income
# 0          2174             0           40  United-States  <=50K
# ...

# %% [markdown]
# Follow the textbook examples to complete the tasks below.  Note that cutting and pasting from the text
# is a bit problematic since they use special quote character in the code - if you try to copy-paste the code you'll get syntax errors. Instead, type out the commands, it might help you remember them better too.
#
# The first task is to create separate dataframes for males and females, and for males and females earning over 50K (four dataframes in all).  When you have done this, **display the mean, median and standard deviation of age for each group** (Section 3.3.1).
#
# One criticism I have of the code in the text is that they use very short variable names like df and ml2.  I've called the main dataframe `adult`; I suggest you use slightly longer varible names (`males`, `males_high`) to make your code easier to read - although avoid really long names (`males_with_high_income`) as they can make your code hard to read.

# %%
# dataframe for males
males = adult[adult["sex"] == "Male"]
males.head()
# Out:
#    age     type_employer  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 7   52  Self-emp-not-inc  209642    HS-grad              9
#
#               marital         occupation   relationship   race   sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White  Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White  Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White  Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black  Male
# 7  Married-civ-spouse    Exec-managerial        Husband  White  Male
#
#    capital_gain  capital_loss  hr_per_week        country income
# 0          2174             0           40  United-States  <=50K
# ...

# %%
# dataframe for females
females = adult[adult["sex"] == "Female"]
females.head()
# Out:
#     age type_employer  fnlwgt  education  education_num  \
# 4    28       Private  338409  Bachelors             13
# 5    37       Private  284582    Masters             14
# 6    49       Private  160187        9th              5
# 8    31       Private   45781    Masters             14
# 12   23       Private  122272  Bachelors             13
#
#                   marital       occupation   relationship   race     sex  \
# 4      Married-civ-spouse   Prof-specialty           Wife  Black  Female
# 5      Married-civ-spouse  Exec-managerial           Wife  White  Female
# 6   Married-spouse-absent    Other-service  Not-in-family  Black  Female
# 8           Never-married   Prof-specialty  Not-in-family  White  Female
# 12          Never-married     Adm-clerical      Own-child  White  Female
#
#     capital_gain  capital_loss  hr_per_week        country income
# 4              0             0           40           Cuba  <=50K
# ...

# %%
# dataframe for males earning over 50k
males_high = males[males["income"] == ">50K"]
males_high.head()
# Out:
#     age     type_employer  fnlwgt     education  education_num  \
# 7    52  Self-emp-not-inc  209642       HS-grad              9
# 9    42           Private  159449     Bachelors             13
# 10   37           Private  280464  Some-college             10
# 11   30         State-gov  141297     Bachelors             13
# 14   40           Private  121772     Assoc-voc             11
#
#                marital       occupation  relationship                race  \
# 7   Married-civ-spouse  Exec-managerial       Husband               White
# 9   Married-civ-spouse  Exec-managerial       Husband               White
# 10  Married-civ-spouse  Exec-managerial       Husband               Black
# 11  Married-civ-spouse   Prof-specialty       Husband  Asian-Pac-Islander
# 14  Married-civ-spouse     Craft-repair       Husband  Asian-Pac-Islander
#
#      sex  capital_gain  capital_loss  hr_per_week        country income
# ...

# %%
# dataframe for females earning over 50k
females_high = females[females["income"] == ">50K"]
females_high.head()
# Out:
#     age     type_employer  fnlwgt    education  education_num  \
# 8    31           Private   45781      Masters             14
# 19   43  Self-emp-not-inc  292175      Masters             14
# 52   47           Private   51835  Prof-school             15
# 67   53           Private  169846      HS-grad              9
# 84   44           Private  343591      HS-grad              9
#
#                marital       occupation   relationship   race     sex  \
# 8        Never-married   Prof-specialty  Not-in-family  White  Female
# 19            Divorced  Exec-managerial      Unmarried  White  Female
# 52  Married-civ-spouse   Prof-specialty           Wife  White  Female
# 67  Married-civ-spouse     Adm-clerical           Wife  White  Female
# 84            Divorced     Craft-repair  Not-in-family  White  Female
#
#     capital_gain  capital_loss  hr_per_week        country income
# 8          14084             0           50  United-States   >50K
# ...

# %%
# mean, median, STD for age of males
mean_males = males["age"].mean()
median_males = males["age"].median()
STD_males = males["age"].std()
print("Mean value of age for males is: ", round(mean_males, 2))
print("Median value of age for males is: ", round(median_males, 2))
print("Standard deviation of age for males is: ", round(STD_males, 2))
# Out:
# Mean value of age for males is:  39.43
# Median value of age for males is:  38.0
# Standard deviation of age for males is:  13.37

# %%
# mean, median, STD for age of females
mean_females = females["age"].mean()
median_females = females["age"].median()
STD_females = females["age"].std()
print("Mean value of age for females is: ", round(mean_females, 2))
print("Median value of age for females is: ", round(median_females, 2))
print("Standard deviation of age for females is: ", round(STD_females, 2))
# Out:
# Mean value of age for females is:  36.86
# Median value of age for females is:  35.0
# Standard deviation of age for females is:  14.01

# %%
# mean, median, STD for age of males with high income
mean_males_high = males_high["age"].mean()
median_males_high = males_high["age"].median()
STD_males_high = males_high["age"].std()
print("Mean value of age for high income males is: ", round(mean_males_high, 2))
print("Median value of age for high income males is: ", round(median_males_high, 2))
print("Standard deviation of age for high income males is: ", round(STD_males_high, 2))
# Out:
# Mean value of age for high income males is:  44.63
# Median value of age for high income males is:  44.0
# Standard deviation of age for high income males is:  10.49

# %%
# mean, median, STD for age of females with high income
mean_females_high = females_high["age"].mean()
median_females_high = females_high["age"].median()
STD_females_high = females_high["age"].std()
print("Mean value of age for high income females is: ", round(mean_females_high, 2))
print("Median value of age for high income females is: ", round(median_females_high, 2))
print("Standard deviation of age for high income females is: ", round(STD_females_high, 2))
# Out:
# Mean value of age for high income females is:  42.13
# Median value of age for high income females is:  41.0
# Standard deviation of age for high income females is:  10.46

# %% [markdown]
# Plot the distributions of the ages of males and females in the dataset on a single graph (Section 3.3.2 figure 3.2).  Note that you can do without using the seaborn module as in the example, just use `color='indianred'` instead.  Work out ([from the pandas documentation](http://pandas.pydata.org/pandas-docs/)) how to add labels to the axes in your plot - the code in the chapter doesn't show this.
#
# Compare your plot with the plot in the textbook.  Does it look the same? If it does, then you made the same error as they did. Compare the y-axis in Figures 3.1 and 3.2 (left) for Males; are there more males or females between ages 30 and 40?
#
# **This week's first checkpoint is to identify the bug in the textbook code.  Tell your tutor where you've found the bug.**

# %%
# distribution of the ages of males and females
males_age = males["age"]
females_age = females["age"]

males_age.hist(histtype='stepfilled', alpha=.5, bins=25, label='Males')
females_age.hist(histtype='stepfilled', alpha=.5, color='indianred', bins=25, label='Females')
plt.xlabel('Age', fontsize=12)
plt.ylabel('Samples', fontsize=12)
plt.title('Distribution of Age among Males and Females', fontsize=14)
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## Outliers
#
# The text book Section 3.3.3 talks about removing outliers from the data, discarding values that lie a long way from the median or mean value.   For this dataset, they talk about removing any rows where the income is >50K but the age is below 22 or above 72 - basically saying that these values are unlikely to be real.   This is a reasonable thing to do but the code they give for it is buggy.
#
# They show this formula:
#
# ```
# df2 = df.drop(df.index[
#                       (df.income == ’>50K\n’) &
#                       (df[’age’] > df[’age’].median() + 35) & (df[’age’] > df[’age’].median() -15)
# ])
# ```
#
# Note that they are dropping from the dataframe `df` any rows where the income is high AND the age is greater than 72 (median + 35) AND the age is greater than 22 (median - 15).   So effectively the last term will have no effect.
# What they really mean is (age > 72) OR (age < 22).  Here are some expressions that express these constraints. I've printed the length of the dataframe after using the boolean expression to select the rows:

# %%
print( len( adult[(adult.income == '>50K')] ))
print( len( adult[(adult.age > 72)] ))
print( len( adult[(adult.age < 22)] ))
print( len( adult[(adult.income == '>50K')  & ((adult.age > 72) | (adult.age < 22))] ))
# Out:
# 7841
# 401
# 3130
# 74

# %% [markdown]
# Based on these expressions, we can drop rows outside of the target range using the `drop` method as in the textbook.  Note the use of `adult.index`.  The argument to drop is a series giving the indexes of the rows we want to remove from the dataframe.   So we filter the index of the dataframe using the boolean expression to get this.

# %%
# remove outliers - people with high income who are too old or too young
adult_clean = adult.drop( adult.index[(adult.income == '>50K') & 
                                      ((adult['age'] > 72) | 
                                       (adult['age'] < 22))]
                        )

# confirm that we have restricted the range of ages for high earners, should see 
adult_clean[adult_clean.income=='>50K'].age.describe()
# Out:
# count    7767.000000
# mean       43.965495
# std        10.044728
# min        22.000000
# 25%        36.000000
# 50%        43.000000
# 75%        51.000000
# max        72.000000
# Name: age, dtype: float64

# %% [markdown]
# Note that unlike in the textbook, the minimum age is now 22 (not 19).
#
# Given this filtered dataset, repeat the analysis in the remainder of section 3.3.3 to **determine whether the difference between males and females is changed once outliers are removed**. To do this you will need to compute versions of the male and female high earners age series with and without outliers removed.  You can do this directly from the `adult` and `adult_clean` dataframes.

# %%
# create "cleaned" dataframes 
males_clean_high = adult_clean.loc[(adult_clean["sex"] == "Male") & (adult_clean["income"] == ">50K")]
females_clean_high = adult_clean.loc[(adult_clean["sex"] == "Female") & (adult_clean["income"] == ">50K")]

# %%
# Statistics for high income men after removing outliers

males_clean_high_mean = males_clean_high["age"].mean()
males_clean_high_median = males_clean_high["age"].median()
males_clean_high_std = males_clean_high["age"].std()
males_clean_high_min = males_clean_high["age"].min()
males_clean_high_max = males_clean_high["age"].max()

print("High income men statistics:\nMean: ", round(males_clean_high_mean, 2),
     "Median: ", round(males_clean_high_median, 2),
     "Standard Deviation: ", round(males_clean_high_std, 2),
     "Min: ", round(males_clean_high_min, 2),
     "Max: ", round(males_clean_high_max, 2))
# Out:
# High income men statistics:
# Mean:  44.33 Median:  44.0 Standard Deviation:  10.01 Min:  22 Max:  72

# %%
# Statistics for high income women after removing outliers

females_clean_high_mean = females_clean_high["age"].mean()
females_clean_high_median = females_clean_high["age"].median()
females_clean_high_std = females_clean_high["age"].std()
females_clean_high_min = females_clean_high["age"].min()
females_clean_high_max = females_clean_high["age"].max()

print("High income women statistics:\nMean: ", round(females_clean_high_mean, 2),
     "Median: ", round(females_clean_high_median, 2),
     "Standard Deviation: ", round(females_clean_high_std, 2),
     "Min: ", round(females_clean_high_min, 2),
     "Max: ", round(females_clean_high_max, 2))
# Out:
# High income women statistics:
# Mean:  41.93 Median:  41.0 Standard Deviation:  9.99 Min:  22 Max:  72

# %%
# Difference between high income men and women after and before outliers are removed

print("Difference after outliers are removed:\nMean: ", round(males_clean_high_mean-females_clean_high_mean, 2),
     "\tMedian: ", round(males_clean_high_median-females_clean_high_median, 2),
     "\tStd. Deviation: ", round(males_clean_high_std-females_clean_high_std, 2), "\n")

print("Difference before outliers are removed:\nMean: ", round(mean_males_high-mean_females_high, 2),
     "\tMedian: ", round(median_males_high-median_females_high, 2),
     "\tStd. Deviation: ", round(STD_males_high-STD_females_high, 2))
# Out:
# Difference after outliers are removed:
# Mean:  2.39 	Median:  3.0 	Std. Deviation:  0.02
#
# Difference before outliers are removed:
# Mean:  2.5 	Median:  3.0 	Std. Deviation:  0.03

# %% [markdown]
# Generate figure 3.5 from the textbook that shows the relative frequency of male an female high earners as a function of age.  Again, label your axes and the plot overall.

# %%
# create two histograms

countx,divisionx = np.histogram(males_clean_high["age"], density=True)
county,divisiony = np.histogram(females_clean_high["age"], density=True)

# %%
# create plot of relative frequency of male and female high earners as a function of age

val = [(divisionx[i]+divisionx[i+1])/2 for i in range(len(divisionx)-1)]
plt.plot(val, countx-county, 'o-') 
plt.title('Differences in promoting men vs. women')
plt.xlabel('Age',fontsize=15)
plt.ylabel('Differences',fontsize=15)
plt.show()

# %% [markdown]
# Finally, use the **Pearson’s median skewness coefficient** from Section 3.3.4 to confirm the difference in the shape of the distribution of male and female age distributions.

# %%
# Pearson's median skewness coefficient

def pearson(x):
    return 3*(x.mean() - x.median())*x.std()

print("Pearson median skewness coefficient for the male population = ", pearson(males_clean_high["age"]))
print("Pearson median skewness coefficient for the female population = ", pearson(females_clean_high["age"]))
# Out:
# Pearson median skewness coefficient for the male population =  9.772577960962293
# Pearson median skewness coefficient for the female population =  27.941592718142346

# %% [markdown]
# Summarise the results of your analysis. Do you reach the same conclusion as the textbook? What if any differences do you observe with the correct removal of outliers?

# %% [markdown]
# ## Write your analysis here

# %% [markdown]
# **This week's final checkpoint is to complete this notebook and also writing your analysis. Writing a brief commentary regarding numbers and plots is very important to highlight what you can conclude from your data exploration.**
#
# **If you need help in finishing this week's notebook, kindly take help from your tutor. Also, refer to Chapter 3 of your textbook**

# %% [markdown]
# By analysing the Adult dataset, the goal was to test whether the hypothesis "_Are men more likely to become high-income professionals than women?_" can be true.<br />
# The approach was to first get a sense for the data in dataset and to create __subgroups for different genders and their respective income groups (high vs. low)__. To dig deeper into these subgroups we calculated some __summary statistics for each group__. After __visualising the distribution of age__ among males and females, it became clear that __outliers had to be removed__ to provide a more accurate picture of income distribution.<br />
# By looking at the age distribution, it was possible to show that __women tend to get promoted earlier in their career than men who tend to have higher income than women by the mid-forties__. However, the question __whether men are generally more likely to earn higher income than women could not be answered__ by the analysis.
# The indication is, though, that the hypothesis is correct. This is due to the fact that __the relative frequency of of older high income earners is higher for men even though there are a lot more women__ in this age group, indicated by the __Pearson's skewness coefficient that was almost three times higher for women__. This coefficient tells that there are more values for older women than for older men.

# %% [markdown]
# ## Challenge
#
# If you complete this work in plenty of time, explore the dataset a little more to
# familiarise yourself with some other features of Pandas dataframes. Example questions might be:
#
# - does education level have an effect on income? Use [groupby](http://pandas.pydata.org/pandas-docs/stable/groupby.html) to look at the different values of the education variable and the number
# of records in each group.  Select one or two groups and compare the low and high income bands for these.
# - The `education_num` column is (I think) a numerical measure of the level of education of the person - higher for a higher level of qualification.  Look at the difference in this variable for groups defined by the `marital` variable: are married people more or less highly educated than those who are single?
